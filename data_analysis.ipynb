# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("School_Learning_Modalities.csv")

# %%
#pd.set_option('max_rows', None)

# %%
df
# Out:
#       District_code     District_name                     Week  \
# 0            100005  Albertville City  2022 Dec 25 12:00:00 AM
# 1            100006   Marshall County  2022 Dec 25 12:00:00 AM
# 2            100007       Hoover City  2022 Dec 25 12:00:00 AM
# 3            100008      Madison City  2022 Dec 25 12:00:00 AM
# 4            100011        Leeds City  2022 Dec 25 12:00:00 AM
# ...             ...               ...                      ...
# 1995        4703450       Polk County  2022 Dec 25 12:00:00 AM
# 1996        4703480     Putnam County  2022 Dec 25 12:00:00 AM
# 1997        4703510       Rhea County  2022 Dec 25 12:00:00 AM
# 1998        4703540      Richard City  2022 Dec 25 12:00:00 AM
# 1999        4703590      Roane County  2022 Dec 25 12:00:00 AM
#
#      Learning_Modality  Operational_Schools Student_Count             City  \
# 0            In Person                    6         5,824      Albertville
# 1            In Person                   15         5,764     Guntersville
# 2            In Person                   18        14,061           Hoover
# 3            In Person                   11        11,695          Madison
# 4            In Person                    4         2,076            Leeds
# ...                ...                  ...           ...              ...
# 1995         In Person                    7         2,269           Benton
# 1996         In Person                   22        11,916       Cookeville
# 1997         In Person                    7         4,225           Dayton
# 1998         In Person                    1           270  South Pittsburg
# 1999         In Person                   18         6,514         Kingston
#
#      State  ZIP_Code
# 0       AL     35950
# 1       AL     35976
# 2       AL     35243
# 3       AL     35758
# 4       AL     35094
# ...    ...       ...
# 1995    TN     37307
# 1996    TN     38506
# 1997    TN     37321
# 1998    TN     37380
# 1999    TN     37763
#
# [2000 rows x 9 columns]

# %%
df.shape
# Out:
# (2000, 9)

# %%
df.head(3)
# Out:
#    District_code     District_name                     Week Learning_Modality  \
# 0         100005  Albertville City  2022 Dec 25 12:00:00 AM         In Person
# 1         100006   Marshall County  2022 Dec 25 12:00:00 AM         In Person
# 2         100007       Hoover City  2022 Dec 25 12:00:00 AM         In Person
#
#    Operational_Schools Student_Count          City State  ZIP_Code
# 0                    6         5,824   Albertville    AL     35950
# 1                   15         5,764  Guntersville    AL     35976
# 2                   18        14,061        Hoover    AL     35243

# %%
df.tail(3)
# Out:
#       District_code District_name                     Week Learning_Modality  \
# 1997        4703510   Rhea County  2022 Dec 25 12:00:00 AM         In Person
# 1998        4703540  Richard City  2022 Dec 25 12:00:00 AM         In Person
# 1999        4703590  Roane County  2022 Dec 25 12:00:00 AM         In Person
#
#       Operational_Schools Student_Count             City State  ZIP_Code
# 1997                    7         4,225           Dayton    TN     37321
# 1998                    1           270  South Pittsburg    TN     37380
# 1999                   18         6,514         Kingston    TN     37763

# %%
df.sample(10)
# Out:
#       District_code                         District_name  \
# 1063        2802490               LAWRENCE CO SCHOOL DIST
# 715         2004140                               Bucklin
# 1235        3016710                     Lima K-12 Schools
# 519         1712240                     Dieterich CUSD 30
# 1201        3003330                          Belgrade H S
# 1770        4019380                             MAYSVILLE
# 622         1806080                     MSD Warren County
# 1919        4221810                            Solanco SD
# 718         2004230                               Central
# 95           405880  Palominas Elementary District (4180)
#
#                          Week Learning_Modality  Operational_Schools  \
# 1063  2022 Dec 25 12:00:00 AM         In Person                    6
# 715   2022 Dec 25 12:00:00 AM         In Person                    2
# 1235  2022 Dec 25 12:00:00 AM         In Person                    3
# 519   2022 Dec 25 12:00:00 AM         In Person                    2
# 1201  2022 Dec 25 12:00:00 AM         In Person                    1
# 1770  2022 Dec 25 12:00:00 AM         In Person                    2
# 622   2022 Dec 25 12:00:00 AM         In Person                    4
# 1919  2022 Dec 25 12:00:00 AM         In Person                    7
# 718   2022 Dec 25 12:00:00 AM         In Person                    2
# 95    2022 Dec 25 12:00:00 AM         In Person                    3
#
#      Student_Count          City State  ZIP_Code
# 1063         2,027    MONTICELLO    MS     39654
# 715            247       Bucklin    KS     67834
# 1235            60          Lima    MT     59739
# 519            558     Dieterich    IL     62424
# 1201         1,001      Belgrade    MT     59714
# 1770           325     Maysville    OK     73057
# 622          1,304  Williamsport    IN     47993
# 1919         3,294   Quarryville    PA     17566
# 718            321        Burden    KS     67019
# 95             957      HEREFORD    AZ     85615

# %%
df.columns
# Out:
# Index(['District_code', 'District_name', 'Week', 'Learning_Modality',
#        'Operational_Schools', 'Student_Count', 'City', 'State', 'ZIP_Code'],
#       dtype='object')

# %%
df['Week'].unique
# Out:
# <bound method Series.unique of 0       2022 Dec 25 12:00:00 AM
# 1       2022 Dec 25 12:00:00 AM
# 2       2022 Dec 25 12:00:00 AM
# 3       2022 Dec 25 12:00:00 AM
# 4       2022 Dec 25 12:00:00 AM
#                  ...
# 1995    2022 Dec 25 12:00:00 AM
# 1996    2022 Dec 25 12:00:00 AM
# 1997    2022 Dec 25 12:00:00 AM
# 1998    2022 Dec 25 12:00:00 AM
# 1999    2022 Dec 25 12:00:00 AM
# Name: Week, Length: 2000, dtype: object>

# %%
df['Week'].value_counts()
# Out:
# 2022 Dec 25 12:00:00 AM    2000
# Name: Week, dtype: int64

# %%
df['Week'].duplicated().sum()
# Out:
# 1999

# %%
df['Learning_Modality'].duplicated().sum()
# Out:
# 1998

# %%
df['Learning_Modality'].unique()
# Out:
# array(['In Person', 'Hybrid'], dtype=object)

# %%
df['Learning_Modality'].value_counts()
# Out:
# In Person    1998
# Hybrid          2
# Name: Learning_Modality, dtype: int64

# %%
df[df['Learning_Modality'] == 'Hybrid']
# Out:
#      District_code                   District_name                     Week  \
# 295         629130             Oroville Union High  2022 Dec 25 12:00:00 AM
# 899        2600322  Covenant House Academy Detroit  2022 Dec 25 12:00:00 AM
#
#     Learning_Modality  Operational_Schools Student_Count      City State  \
# 295            Hybrid                    4         2,237  Oroville    CA
# 899            Hybrid                    3           497   DETROIT    MI
#
#      ZIP_Code
# 295     95966
# 899     48216

# %%
df=df.drop(['Week'], axis=1)

# %%
df
# Out:
#       District_code     District_name Learning_Modality  Operational_Schools  \
# 0            100005  Albertville City         In Person                    6
# 1            100006   Marshall County         In Person                   15
# 2            100007       Hoover City         In Person                   18
# 3            100008      Madison City         In Person                   11
# 4            100011        Leeds City         In Person                    4
# ...             ...               ...               ...                  ...
# 1995        4703450       Polk County         In Person                    7
# 1996        4703480     Putnam County         In Person                   22
# 1997        4703510       Rhea County         In Person                    7
# 1998        4703540      Richard City         In Person                    1
# 1999        4703590      Roane County         In Person                   18
#
#      Student_Count             City State  ZIP_Code
# 0            5,824      Albertville    AL     35950
# 1            5,764     Guntersville    AL     35976
# 2           14,061           Hoover    AL     35243
# 3           11,695          Madison    AL     35758
# 4            2,076            Leeds    AL     35094
# ...            ...              ...   ...       ...
# 1995         2,269           Benton    TN     37307
# 1996        11,916       Cookeville    TN     38506
# 1997         4,225           Dayton    TN     37321
# 1998           270  South Pittsburg    TN     37380
# 1999         6,514         Kingston    TN     37763
#
# [2000 rows x 8 columns]

# %%
df['District_name']
# Out:
# 0       Albertville City
# 1        Marshall County
# 2            Hoover City
# 3           Madison City
# 4             Leeds City
#               ...
# 1995         Polk County
# 1996       Putnam County
# 1997         Rhea County
# 1998        Richard City
# 1999        Roane County
# Name: District_name, Length: 2000, dtype: object

# %%
df[["State",'City',"Operational_Schools"]]
# Out:
#      State             City  Operational_Schools
# 0       AL      Albertville                    6
# 1       AL     Guntersville                   15
# 2       AL           Hoover                   18
# 3       AL          Madison                   11
# 4       AL            Leeds                    4
# ...    ...              ...                  ...
# 1995    TN           Benton                    7
# 1996    TN       Cookeville                   22
# 1997    TN           Dayton                    7
# 1998    TN  South Pittsburg                    1
# 1999    TN         Kingston                   18
#
# [2000 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   District_code        2000 non-null   int64
#  1   District_name        2000 non-null   object
#  2   Learning_Modality    2000 non-null   object
#  3   Operational_Schools  2000 non-null   int64
#  4   Student_Count        1997 non-null   object
#  5   City                 2000 non-null   object
#  6   State                2000 non-null   object
#  7   ZIP_Code             2000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 125.1+ KB

# %%
df.describe()
# Out:
#        District_code  Operational_Schools      ZIP_Code
# count   2.000000e+03          2000.000000   2000.000000
# mean    2.514721e+06             6.504000  51784.701000
# std     1.276482e+06            20.442674  28586.231185
# min     1.000050e+05             1.000000   1022.000000
# 25%     1.709765e+06             2.000000  29307.000000
# 50%     2.700280e+06             3.000000  55421.500000
# 75%     3.615818e+06             6.000000  72473.000000
# max     4.703590e+06           782.000000  99901.000000

# %%
df.isna().sum()
# Out:
# District_code          0
# District_name          0
# Learning_Modality      0
# Operational_Schools    0
# Student_Count          3
# City                   0
# State                  0
# ZIP_Code               0
# dtype: int64

# %%
df[df['Student_Count'].isna()]
# Out:
#       District_code                   District_name Learning_Modality  \
# 1015        2700449  Three Rivers Montessori School         In Person
# 1017        2700466       Rock Ridge Public Schools         In Person
# 1451        3601222       BRILLA PAX CHARTER SCHOOL         In Person
#
#       Operational_Schools Student_Count       City State  ZIP_Code
# 1015                    1           NaN  ELK RIVER    MN     55330
# 1017                    8           NaN   VIRGINIA    MN     55792
# 1451                    1           NaN      BRONX    NY     10468

# %%
df['Student_Count']=df['Student_Count'].fillna('0')

# %%
df[df['Student_Count'].isna()]
# Out:
# Empty DataFrame
# Columns: [District_code, District_name, Learning_Modality, Operational_Schools, Student_Count, City, State, ZIP_Code]
# Index: []

# %%
df['Student_Count']=df['Student_Count'].str.replace(',', '').astype(int)

# %%
df['Student_Count'].max()
# Out:
# 483234

# %%
df.groupby(["State","Operational_Schools"]).mean().reset_index()[['Student_Count']]
# Out:
#      Student_Count
# 0             29.0
# 1            306.0
# 2           2780.0
# 3            618.5
# 4           1203.0
# ..             ...
# 473         6514.0
# 474        11916.0
# 475        13043.0
# 476        36582.0
# 477        85588.0
#
# [478 rows x 1 columns]

# %%
df['City'].value_counts()
# Out:
# WASHINGTON         19
# PHOENIX            13
# SAINT PAUL         10
# Paterson            7
# Columbus            7
#                    ..
# Schleswig           1
# Schaller            1
# Des Moines          1
# Rockford            1
# South Pittsburg     1
# Name: City, Length: 1521, dtype: int64

# %%
df.groupby(["State",'City',"Operational_Schools"]).sum().reset_index()[['Student_Count']]
# Out:
#       Student_Count
# 0                29
# 1             46143
# 2              4245
# 3               336
# 4               791
# ...             ...
# 1738           1613
# 1739           4070
# 1740            270
# 1741           3281
# 1742           2806
#
# [1743 rows x 1 columns]

# %%
#fetching District_name, Operational_Schools, City of 100 to 200 indexed data
df.iloc[100:200,1:7:2]
# Out:
#                              District_name  Operational_Schools          City
# 100               MAGNOLIA SCHOOL DISTRICT                    5      MAGNOLIA
# 101         RIVERCREST SCHOOL DISTRICT #57                    2        WILSON
# 102                 MANILA SCHOOL DISTRICT                    2        MANILA
# 103                TRUMANN SCHOOL DISTRICT                    3       TRUMANN
# 104                DEQUEEN SCHOOL DISTRICT                    5      DE QUEEN
# ..                                     ...                  ...           ...
# 195   STEM Preparatory Elementary District                    1   Los Angeles
# 196     High Tech Elementary Mesa District                    1     San Diego
# 197     KIPP Philosophers Academy District                    1   Los Angeles
# 198                  Alpine County Unified                    3  Markleeville
# 199  Alder Grove Charter School 2 District                    1        Eureka
#
# [100 rows x 3 columns]

# %%
df[df['Student_Count'] > 40000]
# Out:
#       District_code                                      District_name  \
# 36           200180                          Anchorage School District
# 260          622500                                 Long Beach Unified
# 264          622710                                Los Angeles Unified
# 305          634170                        San Bernardino City Unified
# 308          634320                                  San Diego Unified
# 310          634410                              San Francisco Unified
# 357          802340  Aurora Joint District No. 28 of the counties o...
# 409         1100030                District of Columbia Public Schools
# 474         1602100                        JOINT SCHOOL DISTRICT NO. 2
# 782         2200840                                   Jefferson Parish
# 1288        3200480                      WASHOE COUNTY SCHOOL DISTRICT
# 1988        4703180                                    Davidson County
#
#      Learning_Modality  Operational_Schools  Student_Count            City  \
# 36           In Person                   97          46143       Anchorage
# 260          In Person                   84          71712      Long Beach
# 264          In Person                  782         483234     Los Angeles
# 305          In Person                   75          48755  San Bernardino
# 308          In Person                  176         102270       San Diego
# 310          In Person                  114          52811   San Francisco
# 357          In Person                   64          40088          AURORA
# 409          In Person                  115          50971      WASHINGTON
# 474          In Person                   60          40600        MERIDIAN
# 782          In Person                   81          49862          Harvey
# 1288         In Person                  111          67301            RENO
# 1988         In Person                  162          85588       Nashville
#
#      State  ZIP_Code
# 36      AK     99504
# 260     CA     90810
# 264     CA     90017
# 305     CA     92410
# 308     CA     92103
# 310     CA     94102
# 357     CO     80011
# 409     DC     20002
# 474     ID     83642
# 782     LA     70058
# 1288    NV     89520
# 1988    TN     37204

# %%
df[df['Student_Count'] < 1000]
# Out:
#       District_code                           District_name Learning_Modality  \
# 15           100197    Acceleration Day and Evening Academy         In Person
# 16           100199               University Charter School         In Person
# 27           200007  Aleutians East Borough School District         In Person
# 28           200010         Aleutian Region School District         In Person
# 30           200050          Alaska Gateway School District         In Person
# ...             ...                                     ...               ...
# 1977        4672450      Tripp-Delmont School District 33-5         In Person
# 1979        4674520      Viborg-Hurley School District 60-6         In Person
# 1989        4703210                                 Newport         In Person
# 1994        4703420                          Pickett County         In Person
# 1998        4703540                            Richard City         In Person
#
#       Operational_Schools  Student_Count             City State  ZIP_Code
# 15                      1            318           Mobile    AL     36606
# 16                      1            431       Livingston    AL     35470
# 27                      4            234       Sand Point    AK     99661
# 28                      2             29        Anchorage    AK     99518
# 30                      8            409              Tok    AK     99780
# ...                   ...            ...              ...   ...       ...
# 1977                    5            148            Tripp    SD     57376
# 1979                    4            376           Viborg    SD     57070
# 1989                    1            682          Newport    TN     37821
# 1994                    2            642        Byrdstown    TN     38549
# 1998                    1            270  South Pittsburg    TN     37380
#
# [913 rows x 8 columns]

# %%
name_sorted_df = df.sort_values(by='District_name')
name_sorted_df.head()
# Out:
#       District_code                  District_name Learning_Modality  \
# 1579        3700372                 A.C.E. Academy         In Person
# 107          500059  ACADEMICS PLUS CHARTER SCHOOL         In Person
# 127          500059  ACADEMICS PLUS CHARTER SCHOOL         In Person
# 1737        4000803    ACADEMY OF SEMINOLE CHARTER         In Person
# 1738        4002430                            ADA         In Person
#
#       Operational_Schools  Student_Count        City State  ZIP_Code
# 1579                    1            402  Harrisburg    NC     28075
# 107                     3           1552    MAUMELLE    AR     72113
# 127                     3           1552    MAUMELLE    AR     72113
# 1737                    2            283    Seminole    OK     74868
# 1738                    6           2564         Ada    OK     74821

# %%
name_sorted_df = df.sort_values(by=['State','City','District_name'])
name_sorted_df.head()
# Out:
#     District_code                    District_name Learning_Modality  \
# 28         200010  Aleutian Region School District         In Person
# 36         200180        Anchorage School District         In Person
# 25         200001  Lower Kuskokwim School District         In Person
# 31         200060     Cordova City School District         In Person
# 33         200100     Delta/Greely School District         In Person
#
#     Operational_Schools  Student_Count            City State  ZIP_Code
# 28                    2             29       Anchorage    AK     99518
# 36                   97          46143       Anchorage    AK     99504
# 25                   29           4245          Bethel    AK     99559
# 31                    3            336         Cordova    AK     99574
# 33                    5            791  Delta Junction    AK     99737

# %%
df_concat = pd.concat([df,name_sorted_df])
df_concat
# Out:
#       District_code     District_name Learning_Modality  Operational_Schools  \
# 0            100005  Albertville City         In Person                    6
# 1            100006   Marshall County         In Person                   15
# 2            100007       Hoover City         In Person                   18
# 3            100008      Madison City         In Person                   11
# 4            100011        Leeds City         In Person                    4
# ...             ...               ...               ...                  ...
# 1993        4703360             Paris         In Person                    3
# 1982        4702880    McNairy County         In Person                   10
# 1998        4703540      Richard City         In Person                    1
# 1990        4703270      Obion County         In Person                    7
# 1986        4703090     Morgan County         In Person                    8
#
#       Student_Count             City State  ZIP_Code
# 0              5824      Albertville    AL     35950
# 1              5764     Guntersville    AL     35976
# 2             14061           Hoover    AL     35243
# 3             11695          Madison    AL     35758
# 4              2076            Leeds    AL     35094
# ...             ...              ...   ...       ...
# 1993           1613            Paris    TN     38242
# 1982           4070           Selmer    TN     38375
# 1998            270  South Pittsburg    TN     37380
# 1990           3281       Union City    TN     38261
# 1986           2806         Wartburg    TN     37887
#
# [4000 rows x 8 columns]

# %%
df_concat = pd.concat([df,name_sorted_df],keys=['normal','sorted'])
df_concat
# Out:
#              District_code     District_name Learning_Modality  \
# normal 0            100005  Albertville City         In Person
#        1            100006   Marshall County         In Person
#        2            100007       Hoover City         In Person
#        3            100008      Madison City         In Person
#        4            100011        Leeds City         In Person
# ...                    ...               ...               ...
# sorted 1993        4703360             Paris         In Person
#        1982        4702880    McNairy County         In Person
#        1998        4703540      Richard City         In Person
#        1990        4703270      Obion County         In Person
#        1986        4703090     Morgan County         In Person
#
#              Operational_Schools  Student_Count             City State  \
# normal 0                       6           5824      Albertville    AL
#        1                      15           5764     Guntersville    AL
#        2                      18          14061           Hoover    AL
#        3                      11          11695          Madison    AL
#        4                       4           2076            Leeds    AL
# ...                          ...            ...              ...   ...
# sorted 1993                    3           1613            Paris    TN
#        1982                   10           4070           Selmer    TN
#        1998                    1            270  South Pittsburg    TN
#        1990                    7           3281       Union City    TN
#        1986                    8           2806         Wartburg    TN
#
#              ZIP_Code
# normal 0        35950
#        1        35976
#        2        35243
#        3        35758
#        4        35094
# ...               ...
# sorted 1993     38242
#        1982     38375
#        1998     37380
#        1990     38261
#        1986     37887
#
# [4000 rows x 8 columns]

# %%
df_concat.loc['sorted']
# Out:
#       District_code                    District_name Learning_Modality  \
# 28           200010  Aleutian Region School District         In Person
# 36           200180        Anchorage School District         In Person
# 25           200001  Lower Kuskokwim School District         In Person
# 31           200060     Cordova City School District         In Person
# 33           200100     Delta/Greely School District         In Person
# ...             ...                              ...               ...
# 1993        4703360                            Paris         In Person
# 1982        4702880                   McNairy County         In Person
# 1998        4703540                     Richard City         In Person
# 1990        4703270                     Obion County         In Person
# 1986        4703090                    Morgan County         In Person
#
#       Operational_Schools  Student_Count             City State  ZIP_Code
# 28                      2             29        Anchorage    AK     99518
# 36                     97          46143        Anchorage    AK     99504
# 25                     29           4245           Bethel    AK     99559
# 31                      3            336          Cordova    AK     99574
# 33                      5            791   Delta Junction    AK     99737
# ...                   ...            ...              ...   ...       ...
# 1993                    3           1613            Paris    TN     38242
# 1982                   10           4070           Selmer    TN     38375
# 1998                    1            270  South Pittsburg    TN     37380
# 1990                    7           3281       Union City    TN     38261
# 1986                    8           2806         Wartburg    TN     37887
#
# [2000 rows x 8 columns]

# %%
df.apply(lambda x: x[0])
# Out:
# District_code                    100005
# District_name          Albertville City
# Learning_Modality             In Person
# Operational_Schools                   6
# Student_Count                      5824
# City                        Albertville
# State                                AL
# ZIP_Code                          35950
# dtype: object

# %%
pd.pivot_table(df,index=['State','District_name'],values='Student_Count',aggfunc=[np.mean, np.median, min, max, np.std])
# Out:
#                                                       mean        median  \
#                                              Student_Count Student_Count
# State District_name
# AK    Alaska Gateway School District                 409.0         409.0
#       Aleutian Region School District                 29.0          29.0
#       Aleutians East Borough School District         234.0         234.0
#       Anchorage School District                    46143.0       46143.0
#       Bering Strait School District                 1900.0        1900.0
# ...                                                    ...           ...
# TN    Polk County                                   2269.0        2269.0
#       Putnam County                                11916.0       11916.0
#       Rhea County                                   4225.0        4225.0
#       Richard City                                   270.0         270.0
#       Roane County                                  6514.0        6514.0
#
#                                                        min           max  \
#                                              Student_Count Student_Count
# State District_name
# AK    Alaska Gateway School District                   409           409
#       Aleutian Region School District                   29            29
#       Aleutians East Borough School District           234           234
#       Anchorage School District                      46143         46143
#       Bering Strait School District                   1900          1900
# ...                                                    ...           ...
# TN    Polk County                                     2269          2269
#       Putnam County                                  11916         11916
#       Rhea County                                     4225          4225
#       Richard City                                     270           270
#       Roane County                                    6514          6514
#
#                                                        std
#                                              Student_Count
# State District_name
# AK    Alaska Gateway School District                   NaN
#       Aleutian Region School District                  NaN
#       Aleutians East Borough School District           NaN
#       Anchorage School District                        NaN
#       Bering Strait School District                    NaN
# ...                                                    ...
# TN    Polk County                                      NaN
#       Putnam County                                    NaN
#       Rhea County                                      NaN
#       Richard City                                     NaN
#       Roane County                                     NaN
#
# [1817 rows x 5 columns]

# %%
df
# Out:
#       District_code     District_name Learning_Modality  Operational_Schools  \
# 0            100005  Albertville City         In Person                    6
# 1            100006   Marshall County         In Person                   15
# 2            100007       Hoover City         In Person                   18
# 3            100008      Madison City         In Person                   11
# 4            100011        Leeds City         In Person                    4
# ...             ...               ...               ...                  ...
# 1995        4703450       Polk County         In Person                    7
# 1996        4703480     Putnam County         In Person                   22
# 1997        4703510       Rhea County         In Person                    7
# 1998        4703540      Richard City         In Person                    1
# 1999        4703590      Roane County         In Person                   18
#
#       Student_Count             City State  ZIP_Code
# 0              5824      Albertville    AL     35950
# 1              5764     Guntersville    AL     35976
# 2             14061           Hoover    AL     35243
# 3             11695          Madison    AL     35758
# 4              2076            Leeds    AL     35094
# ...             ...              ...   ...       ...
# 1995           2269           Benton    TN     37307
# 1996          11916       Cookeville    TN     38506
# 1997           4225           Dayton    TN     37321
# 1998            270  South Pittsburg    TN     37380
# 1999           6514         Kingston    TN     37763
#
# [2000 rows x 8 columns]

# %%
#df.to_csv("School_Learning_Modalities_cleaned_data.csv", index=False)
