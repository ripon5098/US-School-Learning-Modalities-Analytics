# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("School_Learning_Modalities.csv")

# %%
#pd.set_option('max_rows', None)

# %%
df
# Out:
#        District_code             District_name                     Week  \
# 0             100005          Albertville City  2022 Dec 25 12:00:00 AM
# 1             100006           Marshall County  2022 Dec 25 12:00:00 AM
# 2             100007               Hoover City  2022 Dec 25 12:00:00 AM
# 3             100008              Madison City  2022 Dec 25 12:00:00 AM
# 4             100011                Leeds City  2022 Dec 25 12:00:00 AM
# ...              ...                       ...                      ...
# 18815         623940   Mariposa County Unified  2022 Oct 30 12:00:00 AM
# 18816         624030          Martinez Unified  2022 Oct 30 12:00:00 AM
# 18817         624090  Marysville Joint Unified  2022 Oct 30 12:00:00 AM
# 18818         624150           Maxwell Unified  2022 Oct 30 12:00:00 AM
# 18819         624180   McCabe Union Elementary  2022 Oct 30 12:00:00 AM
#
#       Learning_Modality  Operational_Schools Student_Count          City  \
# ...

# %%
df.shape
# Out:
# (18820, 9)

# %%
df.head(3)
# Out:
#    District_code     District_name                     Week Learning_Modality  \
# 0         100005  Albertville City  2022 Dec 25 12:00:00 AM         In Person
# 1         100006   Marshall County  2022 Dec 25 12:00:00 AM         In Person
# 2         100007       Hoover City  2022 Dec 25 12:00:00 AM         In Person
#
#    Operational_Schools Student_Count          City State  ZIP_Code
# 0                    6         5,824   Albertville    AL     35950
# 1                   15         5,764  Guntersville    AL     35976
# 2                   18        14,061        Hoover    AL     35243

# %%
df.tail(3)
# Out:
#        District_code             District_name                     Week  \
# 18817         624090  Marysville Joint Unified  2022 Oct 30 12:00:00 AM
# 18818         624150           Maxwell Unified  2022 Oct 30 12:00:00 AM
# 18819         624180   McCabe Union Elementary  2022 Oct 30 12:00:00 AM
#
#       Learning_Modality  Operational_Schools Student_Count        City State  \
# 18817         In Person                   22         9,969  Marysville    CA
# 18818         In Person                    3           343     Maxwell    CA
# 18819         In Person                    1         1,359   El Centro    CA
#
#        ZIP_Code
# 18817     95901
# 18818     95955
# 18819     92243

# %%
df.sample(10)
# Out:
#        District_code                  District_name                     Week  \
# 3882         3904424            Logan-Hocking Local  2022 Dec 18 12:00:00 AM
# 9096         5300380  Battle Ground School District  2022 Dec 04 12:00:00 AM
# 7538         1809120  John Glenn School Corporation  2022 Dec 04 12:00:00 AM
# 14706        2600121   Honey Creek Community School  2022 Nov 13 12:00:00 AM
# 8156         3304230        Lebanon School District  2022 Dec 04 12:00:00 AM
# 459          1602250         MOUNTAIN HOME DISTRICT  2022 Dec 25 12:00:00 AM
# 1044         2802520           LEAKE CO SCHOOL DIST  2022 Dec 25 12:00:00 AM
# 18120        4704020                  Sumner County  2022 Nov 06 12:00:00 AM
# 8702         4203660                  Big Spring SD  2022 Dec 04 12:00:00 AM
# 4249         4800127               COMQUEST ACADEMY  2022 Dec 18 12:00:00 AM
#
#       Learning_Modality  Operational_Schools Student_Count           City  \
# ...

# %%
df.columns
# Out:
# Index(['District_code', 'District_name', 'Week', 'Learning_Modality',
#        'Operational_Schools', 'Student_Count', 'City', 'State', 'ZIP_Code'],
#       dtype='object')

# %%
df['Week'].unique
# Out:
# <bound method Series.unique of 0        2022 Dec 25 12:00:00 AM
# 1        2022 Dec 25 12:00:00 AM
# 2        2022 Dec 25 12:00:00 AM
# 3        2022 Dec 25 12:00:00 AM
# 4        2022 Dec 25 12:00:00 AM
#                   ...
# 18815    2022 Oct 30 12:00:00 AM
# 18816    2022 Oct 30 12:00:00 AM
# 18817    2022 Oct 30 12:00:00 AM
# 18818    2022 Oct 30 12:00:00 AM
# 18819    2022 Oct 30 12:00:00 AM
# Name: Week, Length: 18820, dtype: object>

# %%
df['Week'].value_counts()
# Out:
# 2022 Nov 06 12:00:00 AM    2340
# 2022 Nov 27 12:00:00 AM    2330
# 2022 Dec 25 12:00:00 AM    2318
# 2022 Nov 20 12:00:00 AM    2310
# 2022 Dec 18 12:00:00 AM    2302
# 2022 Dec 11 12:00:00 AM    2300
# 2022 Dec 04 12:00:00 AM    2300
# 2022 Nov 13 12:00:00 AM    2300
# 2022 Oct 30 12:00:00 AM     320
# Name: Week, dtype: int64

# %%
df['Learning_Modality'].unique()
# Out:
# array(['In Person', 'Hybrid', 'Remote'], dtype=object)

# %%
df['Learning_Modality'].value_counts()
# Out:
# In Person    18760
# Hybrid          52
# Remote           8
# Name: Learning_Modality, dtype: int64

# %%
df[df['Learning_Modality'] == 'Remote']
# Out:
#        District_code                          District_name  \
# 6286         4006000                                 BUTNER
# 6352         4033180                               WOODWARD
# 7799         2601074                           WAY Michigan
# 9292          400999  Freedom Preparatory Academy (1000979)
# 15998        4900196             Leadership Academy of Utah
# 17504        3500117          CESAR CHAVEZ COMMUNITY SCHOOL
# 18332        4900138               Mountain Heights Academy
# 18577         400999  Freedom Preparatory Academy (1000979)
#
#                           Week Learning_Modality  Operational_Schools  \
# 6286   2022 Dec 11 12:00:00 AM            Remote                    2
# 6352   2022 Dec 11 12:00:00 AM            Remote                    7
# 7799   2022 Dec 04 12:00:00 AM            Remote                    1
# 9292   2022 Nov 27 12:00:00 AM            Remote                    1
# 15998  2022 Nov 13 12:00:00 AM            Remote                    1
# ...

# %%
df=df.drop(['District_code'], axis=1)

# %%
df=df.drop(['ZIP_Code'], axis=1)

# %%
df
# Out:
#                   District_name                     Week Learning_Modality  \
# 0              Albertville City  2022 Dec 25 12:00:00 AM         In Person
# 1               Marshall County  2022 Dec 25 12:00:00 AM         In Person
# 2                   Hoover City  2022 Dec 25 12:00:00 AM         In Person
# 3                  Madison City  2022 Dec 25 12:00:00 AM         In Person
# 4                    Leeds City  2022 Dec 25 12:00:00 AM         In Person
# ...                         ...                      ...               ...
# 18815   Mariposa County Unified  2022 Oct 30 12:00:00 AM         In Person
# 18816          Martinez Unified  2022 Oct 30 12:00:00 AM         In Person
# 18817  Marysville Joint Unified  2022 Oct 30 12:00:00 AM         In Person
# 18818           Maxwell Unified  2022 Oct 30 12:00:00 AM         In Person
# 18819   McCabe Union Elementary  2022 Oct 30 12:00:00 AM         In Person
#
#        Operational_Schools Student_Count          City State
# ...

# %%
df['State'].unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'GA', 'ID',
#        'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MA', 'MI', 'MN', 'MS',
#        'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH',
#        'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA',
#        'WA', 'WV', 'WI', 'BI', 'PR', 'FL', 'WY', 'MD', 'HI'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Albertville', 'Guntersville', 'Hoover', ..., 'Wauzeka',
#        'West Allis', 'West Bend'], dtype=object)

# %%
df['City'].value_counts()
# Out:
# PHOENIX          132
# BRONX             68
# WASHINGTON        60
# BROOKLYN          58
# Philadelphia      56
#                 ...
# GILBERTSVILLE      1
# FORT CALHOUN       1
# FREMONT            1
# OSHKOSH            1
# West Bend          1
# Name: City, Length: 7181, dtype: int64

# %%
df['District_name'].unique()
# Out:
# array(['Albertville City', 'Marshall County', 'Hoover City', ...,
#        'West Bend School District', 'West De Pere School District',
#        'Valor Preparatory Academy LLC (1000291)'], dtype=object)

# %%
df['District_name'].value_counts()
# Out:
# Hope Elementary                            8
# Jefferson County                           7
# Montgomery County                          7
# Monroe County                              7
# Madison County                             7
#                                           ..
# Delphos City                               1
# Dover City                                 1
# East Cleveland City School District        1
# East Liverpool City                        1
# Valor Preparatory Academy LLC (1000291)    1
# Name: District_name, Length: 10971, dtype: int64

# %%
df[["State",'City',"Operational_Schools"]]
# Out:
#       State          City  Operational_Schools
# 0        AL   Albertville                    6
# 1        AL  Guntersville                   15
# 2        AL        Hoover                   18
# 3        AL       Madison                   11
# 4        AL         Leeds                    4
# ...     ...           ...                  ...
# 18815    CA      Mariposa                   11
# 18816    CA      Martinez                    9
# 18817    CA    Marysville                   22
# 18818    CA       Maxwell                    3
# 18819    CA     El Centro                    1
#
# [18820 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18820 entries, 0 to 18819
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   District_name        18820 non-null  object
#  1   Week                 18820 non-null  object
#  2   Learning_Modality    18820 non-null  object
#  3   Operational_Schools  18820 non-null  int64
#  4   Student_Count        18801 non-null  object
#  5   City                 18820 non-null  object
#  6   State                18820 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        Operational_Schools
# count         18820.000000
# mean              7.288417
# std              20.530072
# min               1.000000
# 25%               2.000000
# 50%               3.000000
# 75%               6.000000
# max             849.000000

# %%
df.isna().sum()
# Out:
# District_name           0
# Week                    0
# Learning_Modality       0
# Operational_Schools     0
# Student_Count          19
# City                    0
# State                   0
# dtype: int64

# %%
df[df['Student_Count'].isna()]
# Out:
#                                            District_name  \
# 995                       Three Rivers Montessori School
# 997                            Rock Ridge Public Schools
# 1391                           BRILLA PAX CHARTER SCHOOL
# 2683                            Sussex Montessori School
# 3067               Warren Easton Charter Foundation Inc.
# 3524                             VERDIGRE PUBLIC SCHOOLS
# 5808                           SUMMERLAND PUBLIC SCHOOLS
# 8434                         Achievement Charter Academy
# 9095                      Impact | Salish Sea Elementary
# 9291   Legacy Traditional School - North Phoenix (100...
# 9292               Freedom Preparatory Academy (1000979)
# 10226                     Three Rivers Montessori School
# 10228                          Rock Ridge Public Schools
# 10622                          BRILLA PAX CHARTER SCHOOL
# 12304              Warren Easton Charter Foundation Inc.
# ...

# %%
df['Student_Count']=df['Student_Count'].fillna('0')

# %%
df[df['Student_Count'].isna()]
# Out:
# Empty DataFrame
# Columns: [District_name, Week, Learning_Modality, Operational_Schools, Student_Count, City, State]
# Index: []

# %%
df['Student_Count']=df['Student_Count'].str.replace(',', '').astype(int)

# %%
df['Student_Count'].max()
# Out:
# 483234

# %%
df['Operational_Schools'].max()
# Out:
# 849

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18820 entries, 0 to 18819
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   District_name        18820 non-null  object
#  1   Week                 18820 non-null  object
#  2   Learning_Modality    18820 non-null  object
#  3   Operational_Schools  18820 non-null  int64
#  4   Student_Count        18820 non-null  int32
#  5   City                 18820 non-null  object
#  6   State                18820 non-null  object
# dtypes: int32(1), int64(1), object(5)
# memory usage: 955.8+ KB

# %%
import datetime

# %%
df['Start_date'] = pd.to_datetime(df['Week'], format="%Y %b %d %I:%M:%S %p")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18820 entries, 0 to 18819
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   District_name        18820 non-null  object
#  1   Week                 18820 non-null  object
#  2   Learning_Modality    18820 non-null  object
#  3   Operational_Schools  18820 non-null  int64
#  4   Student_Count        18820 non-null  int32
#  5   City                 18820 non-null  object
#  6   State                18820 non-null  object
#  7   Start_date           18820 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), int64(1), object(5)
# memory usage: 1.1+ MB

# %%
df.head(3)
# Out:
#       District_name                     Week Learning_Modality  \
# 0  Albertville City  2022 Dec 25 12:00:00 AM         In Person
# 1   Marshall County  2022 Dec 25 12:00:00 AM         In Person
# 2       Hoover City  2022 Dec 25 12:00:00 AM         In Person
#
#    Operational_Schools  Student_Count          City State Start_date
# 0                    6           5824   Albertville    AL 2022-12-25
# 1                   15           5764  Guntersville    AL 2022-12-25
# 2                   18          14061        Hoover    AL 2022-12-25

# %%
df=df.drop(['Week'], axis=1)

# %%
df.sample(3)
# Out:
#                       District_name Learning_Modality  Operational_Schools  \
# 2230            WOOD COUNTY SCHOOLS         In Person                   26
# 12711  Huntley Project K-12 Schools         In Person                    3
# 17972              Blue Mountain SD         In Person                    5
#
#        Student_Count         City State Start_date
# 2230           12238  PARKERSBURG    WV 2022-12-25
# 12711            764       Worden    MT 2022-11-20
# 17972           2564   Orwigsburg    PA 2022-11-06

# %%
df.groupby(["State","Operational_Schools"]).mean().reset_index()[['Student_Count']]
# Out:
#       Student_Count
# 0        140.000000
# 1        146.400000
# 2        346.750000
# 3       2152.111111
# 4        618.500000
# ...             ...
# 1263    2965.250000
# 1264    1660.000000
# 1265    4773.000000
# 1266    8877.000000
# 1267   14421.000000
#
# [1268 rows x 1 columns]

# %%
df['City'].value_counts()
# Out:
# PHOENIX          132
# BRONX             68
# WASHINGTON        60
# BROOKLYN          58
# Philadelphia      56
#                 ...
# GILBERTSVILLE      1
# FORT CALHOUN       1
# FREMONT            1
# OSHKOSH            1
# West Bend          1
# Name: City, Length: 7181, dtype: int64

# %%
df.groupby(["State",'City',"Operational_Schools"]).sum().reset_index()[['Student_Count']]
# Out:
#        Student_Count
# 0                 58
# 1                510
# 2             138429
# 3                406
# 4               8490
# ...              ...
# 10237           2402
# 10238            218
# 10239           1318
# 10240           3320
# 10241            470
#
# [10242 rows x 1 columns]

# %%
#fetching District_name, Operational_Schools, City of 100 to 200 indexed data
df.iloc[100:200,0:6:2]
# Out:
#                       District_name  Operational_Schools             City
# 100        MAGNOLIA SCHOOL DISTRICT                    5         MAGNOLIA
# 101  RIVERCREST SCHOOL DISTRICT #57                    2           WILSON
# 102          MANILA SCHOOL DISTRICT                    2           MANILA
# 103         TRUMANN SCHOOL DISTRICT                    3          TRUMANN
# 104         DEQUEEN SCHOOL DISTRICT                    5         DE QUEEN
# ..                              ...                  ...              ...
# 195                Bogus Elementary                    1         Montague
# 196              Santa Maria-Bonita                   21      Santa Maria
# 197                  Bonita Unified                   15        San Dimas
# 198         Borrego Springs Unified                    3  Borrego Springs
# 199        Bradley Union Elementary                    1          Bradley
#
# [100 rows x 3 columns]

# %%
df[df['Student_Count'] > 40000]
# Out:
#                      District_name Learning_Modality  Operational_Schools  \
# 36       Anchorage School District         In Person                   97
# 240             Long Beach Unified         In Person                   84
# 244            Los Angeles Unified         In Person                  782
# 285    San Bernardino City Unified         In Person                   75
# 288              San Diego Unified         In Person                  176
# ...                            ...               ...                  ...
# 18220                   HUMBLE ISD         In Person                   49
# 18262                NORTHSIDE ISD         In Person                  121
# 18289              SAN ANTONIO ISD         In Person                   99
# 18310                   UNITED ISD         In Person                   51
# 18526    Anchorage School District         In Person                   97
#
#        Student_Count            City State Start_date
# ...

# %%
df[df['Student_Count'] < 1000]
# Out:
#                                 District_name Learning_Modality  \
# 15       Acceleration Day and Evening Academy         In Person
# 16                  University Charter School         In Person
# 27     Aleutians East Borough School District         In Person
# 28            Aleutian Region School District         In Person
# 30             Alaska Gateway School District         In Person
# ...                                       ...               ...
# 18811                    Manzanita Elementary         In Person
# 18812                  Maple Creek Elementary         In Person
# 18813        Marcum-Illinois Union Elementary         In Person
# 18814                        Maricopa Unified         In Person
# 18818                         Maxwell Unified         In Person
#
#        Operational_Schools  Student_Count           City State Start_date
# 15                       1            318         Mobile    AL 2022-12-25
# ...

# %%
name_sorted_df = df.sort_values(by='District_name')
name_sorted_df.head()
# Out:
#                                 District_name Learning_Modality  \
# 2234   21st Century Preparatory School Agency         In Person
# 11466  21st Century Preparatory School Agency         In Person
# 13499                              A+ ACADEMY         In Person
# 1944                               A+ ACADEMY         In Person
# 7377                     A-C Central CUSD 262         In Person
#
#        Operational_Schools  Student_Count     City State Start_date
# 2234                     1            551   Racine    WI 2022-12-25
# 11466                    1            551   Racine    WI 2022-11-27
# 13499                    2           1399   DALLAS    TX 2022-11-20
# 1944                     2           1399   DALLAS    TX 2022-12-25
# 7377                     3            395  Ashland    IL 2022-12-04

# %%
name_sorted_df = df.sort_values(by='Start_date')
name_sorted_df.head()
# Out:
#                           District_name Learning_Modality  \
# 18819           McCabe Union Elementary         In Person
# 18601   IMBODEN CHARTER SCHOOL DISTRICT         In Person
# 18602  LAFAYETTE COUNTY SCHOOL DISTRICT         In Person
# 18603     CLEVELAND COUNTY SCHOOL DIST.         In Person
# 18604       CEDAR RIDGE SCHOOL DISTRICT         In Person
#
#        Operational_Schools  Student_Count        City State Start_date
# 18819                    1           1359   El Centro    CA 2022-10-30
# 18601                    1             58     IMBODEN    AR 2022-10-30
# 18602                    2            545  LEWISVILLE    AR 2022-10-30
# 18603                    2            840       RISON    AR 2022-10-30
# 18604                    2            699      NEWARK    AR 2022-10-30

# %%
name_sorted_df = df.sort_values(by=['State','City','District_name'])
name_sorted_df.head()
# Out:
#                          District_name Learning_Modality  Operational_Schools  \
# 28     Aleutian Region School District         In Person                    2
# 11578  Aleutian Region School District         In Person                    2
# 36           Anchorage School District         In Person                   97
# 9240         Anchorage School District         In Person                   97
# 18526        Anchorage School District         In Person                   97
#
#        Student_Count       City State Start_date
# 28                29  Anchorage    AK 2022-12-25
# 11578             29  Anchorage    AK 2022-11-20
# 36             46143  Anchorage    AK 2022-12-25
# 9240           46143  Anchorage    AK 2022-11-27
# 18526          46143  Anchorage    AK 2022-10-30

# %%
df_concat = pd.concat([df,name_sorted_df])
df_concat
# Out:
#                                District_name Learning_Modality  \
# 0                           Albertville City         In Person
# 1                            Marshall County         In Person
# 2                                Hoover City         In Person
# 3                               Madison City         In Person
# 4                                 Leeds City         In Person
# ...                                      ...               ...
# 16154  Hot Springs County School District #1         In Person
# 6911        Goshen County School District #1         In Person
# 16151       Goshen County School District #1         In Person
# 4609        Weston County School District #7         In Person
# 13842       Weston County School District #7         In Person
#
#        Operational_Schools  Student_Count          City State Start_date
# 0                        6           5824   Albertville    AL 2022-12-25
# ...

# %%
df_concat = pd.concat([df,name_sorted_df],keys=['normal','sorted'])
df_concat
# Out:
#                                       District_name Learning_Modality  \
# normal 0                           Albertville City         In Person
#        1                            Marshall County         In Person
#        2                                Hoover City         In Person
#        3                               Madison City         In Person
#        4                                 Leeds City         In Person
# ...                                             ...               ...
# sorted 16154  Hot Springs County School District #1         In Person
#        6911        Goshen County School District #1         In Person
#        16151       Goshen County School District #1         In Person
#        4609        Weston County School District #7         In Person
#        13842       Weston County School District #7         In Person
#
#               Operational_Schools  Student_Count          City State  \
# ...

# %%
df_concat.loc['sorted']
# Out:
#                                District_name Learning_Modality  \
# 28           Aleutian Region School District         In Person
# 11578        Aleutian Region School District         In Person
# 36                 Anchorage School District         In Person
# 9240               Anchorage School District         In Person
# 18526              Anchorage School District         In Person
# ...                                      ...               ...
# 16154  Hot Springs County School District #1         In Person
# 6911        Goshen County School District #1         In Person
# 16151       Goshen County School District #1         In Person
# 4609        Weston County School District #7         In Person
# 13842       Weston County School District #7         In Person
#
#        Operational_Schools  Student_Count         City State Start_date
# 28                       2             29    Anchorage    AK 2022-12-25
# ...

# %%
df.apply(lambda x: x[0])
# Out:
# District_name             Albertville City
# Learning_Modality                In Person
# Operational_Schools                      6
# Student_Count                         5824
# City                           Albertville
# State                                   AL
# Start_date             2022-12-25 00:00:00
# dtype: object

# %%
pd.pivot_table(df,index=['State','District_name'],values='Student_Count',aggfunc=[np.mean, np.median, min, max, np.std])
# Out:
#                                                       mean        median  \
#                                              Student_Count Student_Count
# State District_name
# AK    Alaska Gateway School District                 409.0         409.0
#       Aleutian Region School District                 29.0          29.0
#       Aleutians East Borough School District         234.0         234.0
#       Anchorage School District                    46143.0       46143.0
#       Bering Strait School District                 1900.0        1900.0
# ...                                                    ...           ...
# WY    Uinta County School District #1               2764.0        2764.0
#       Uinta County School District #4                825.0         825.0
#       Uinta County School District #6                720.0         720.0
#       Washakie County School District #2             109.0         109.0
#       Weston County School District #7               235.0         235.0
# ...

# %%
df
# Out:
#                   District_name Learning_Modality  Operational_Schools  \
# 0              Albertville City         In Person                    6
# 1               Marshall County         In Person                   15
# 2                   Hoover City         In Person                   18
# 3                  Madison City         In Person                   11
# 4                    Leeds City         In Person                    4
# ...                         ...               ...                  ...
# 18815   Mariposa County Unified         In Person                   11
# 18816          Martinez Unified         In Person                    9
# 18817  Marysville Joint Unified         In Person                   22
# 18818           Maxwell Unified         In Person                    3
# 18819   McCabe Union Elementary         In Person                    1
#
#        Student_Count          City State Start_date
# 0               5824   Albertville    AL 2022-12-25
# ...

# %%
df.to_csv("School_Learning_Modalities_cleaned_data.csv", index=False)
